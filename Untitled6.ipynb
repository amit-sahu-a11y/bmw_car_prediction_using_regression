# %% [markdown]
# <a href="https://colab.research.google.com/github/amit-sahu-a11y/bmw_car_prediction_using_regression/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/bmw.csv')

# %%
df.shape
# Out:
# (10781, 9)

# %%
df.describe()
# Out:
#                year          price        mileage           tax           mpg  \
# count  10781.000000   10781.000000   10781.000000  10781.000000  10781.000000
# mean    2017.078935   22733.408867   25496.986550    131.702068     56.399035
# std        2.349038   11415.528189   25143.192559     61.510755     31.336958
# min     1996.000000    1200.000000       1.000000      0.000000      5.500000
# 25%     2016.000000   14950.000000    5529.000000    135.000000     45.600000
# 50%     2017.000000   20462.000000   18347.000000    145.000000     53.300000
# 75%     2019.000000   27940.000000   38206.000000    145.000000     62.800000
# max     2020.000000  123456.000000  214000.000000    580.000000    470.800000
#
#          engineSize
# count  10781.000000
# mean       2.167767
# std        0.552054
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        6.600000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10781 entries, 0 to 10780
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10781 non-null  object
#  1   year          10781 non-null  int64
#  2   price         10781 non-null  int64
#  3   transmission  10781 non-null  object
#  4   mileage       10781 non-null  int64
#  5   fuelType      10781 non-null  object
#  6   tax           10781 non-null  int64
#  7   mpg           10781 non-null  float64
#  8   engineSize    10781 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 758.2+ KB

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(117)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
x=df.drop(columns=['price'],axis=1)
y=df['price']

# %%
meann=df['price'].mean()

# %%
x.shape
# Out:
# (10664, 8)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %%
df['fuelType'].value_counts()
# Out:
# fuelType
# Diesel      6988
# Petrol      3340
# Hybrid       297
# Other         36
# Electric       3
# Name: count, dtype: int64

# %%
cat=['model','transmission','fuelType']
num=['year','mileage','tax','mpg','engineSize']

# %%
cat_pipe=Pipeline(
    steps=[
        ("encoded",OneHotEncoder(drop="first",sparse_output=False,handle_unknown='ignore')),
    ]
)

# %%
num_pip=Pipeline(
    steps=[
        ("scaled",StandardScaler())
    ]
)

# %%
preprocessor=ColumnTransformer(
    transformers=[
        ('cat',cat_pipe,cat),
        ('num',num_pip,num)
    ]
)

# %%
final=Pipeline(
    steps=[
        ('preprocessor',preprocessor),
        ('model',LinearRegression())
    ]
)

# %%
final.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('encoded',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['model', 'transmission',
#                                                    'fuelType']),
#                                                  ('num',
#                                                   Pipeline(steps=[('scaled',
#                                                                    StandardScaler())]),
#                                                   ['year', 'mileage', 'tax',
# ...

# %%
x_train.head()
# Out:
#           model  year transmission  mileage fuelType  tax   mpg  engineSize
# 8650   1 Series  2014    Automatic    29626   Petrol  125  50.4         1.6
# 2368   5 Series  2016    Semi-Auto    31570   Diesel   30  62.8         2.0
# 8138   1 Series  2013       Manual    67916   Diesel   30  65.7         2.0
# 7006   2 Series  2018    Semi-Auto    25029   Petrol  145  39.8         3.0
# 9499   3 Series  2012    Automatic    75840   Diesel  145  53.3         2.0

# %%
from sklearn.metrics import mean_absolute_error
y_train_pred=final.predict(x_train)
error=mean_absolute_error(y_train,y_train_pred)
error
# Out:
# 2775.0873543058296

# %%
er=(error/y_train.mean())*100
er
# Out:
# np.float64(12.239087931069975)

# %%
from sklearn.metrics import r2_score

y_pred = final.predict(x_train)
print(r2_score(y_train, y_pred))
# Out:
# 0.86609392711461

# %%
from sklearn.metrics import r2_score

y_pred = final.predict(x_test)
print(r2_score(y_test, y_pred))
# Out:
# 0.8726837198271149
